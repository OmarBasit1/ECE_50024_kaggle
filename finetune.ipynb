# %% [markdown]
# # Face detection and recognition training pipeline
#
# The following example illustrates how to fine-tune an InceptionResnetV1 model on your own dataset. This will mostly follow standard pytorch training patterns.

# %%
from facenet_pytorch import MTCNN, InceptionResnetV1, fixed_image_standardization, training
import torch
from torch.utils.data import DataLoader, SubsetRandomSampler
from torch import optim
from torch.optim.lr_scheduler import MultiStepLR
from torch.utils.tensorboard import SummaryWriter
from torchvision import datasets, transforms
import numpy as np
import os
import pandas as pd
import glob 
from PIL import Image
import matplotlib.pyplot as plt
from IPython.display import display

# %% [markdown]
# #### Define run parameters
#
# The dataset should follow the VGGFace2/ImageNet-style directory layout. Modify `data_dir` to the location of the dataset on wish to finetune on.

# %%
data_dir = '/export2/obasit/50024/kaggle_data/train/train_mtcnn'

batch_size = 150
epochs = 7
workers = 0 if os.name == 'nt' else 16

# %% [markdown]
# #### Determine if an nvidia GPU is available

# %%
device = torch.device('cuda:1' if torch.cuda.is_available() else 'cpu')
# device = torch.device('cpu')
print('Running on device: {}'.format(device))
# Out:
# Running on device: cuda:1

# %% [markdown]
# #### Define MTCNN module
#
# See `help(MTCNN)` for more details.

# %%
mtcnn = MTCNN(
    image_size=160, margin=40, min_face_size=40,
    thresholds=[0.6, 0.7, 0.7], factor=0.709, post_process=True,
    device=device, 
    selection_method='largest_over_threshold', keep_all=True
)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 mtcnn = MTCNN(
#       2     image_size=160, margin=40, min_face_size=40,
#       3     thresholds=[0.6, 0.7, 0.7], factor=0.709, post_process=True,
#       4     device=device,
#       5     selection_method='largest_over_threshold', keep_all=True
#       6 )
#
# File ~/50024/kaggle/kaggle_env/lib/python3.11/site-packages/facenet_pytorch/models/mtcnn.py:221, in MTCNN.__init__(self, image_size, margin, min_face_size, thresholds, factor, post_process, select_largest, selection_method, keep_all, device)
#     219 if device is not None:
#     220     self.device = device
# --> 221     self.to(device)
#     223 if not self.selection_method:
#     224     self.selection_method = 'largest' if self.select_largest else 'probability'
#
# File ~/50024/kaggle/kaggle_env/lib/python3.11/site-packages/torch/nn/modules/module.py:1152, in Module.to(self, *args, **kwargs)
#    1148         return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None,
#    1149                     non_blocking, memory_format=convert_to_format)
#    1150     return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None, non_blocking)
# -> 1152 return self._apply(convert)
#
# File ~/50024/kaggle/kaggle_env/lib/python3.11/site-packages/torch/nn/modules/module.py:802, in Module._apply(self, fn, recurse)
#     800 if recurse:
#     801     for module in self.children():
# --> 802         module._apply(fn)
#     804 def compute_should_use_set_data(tensor, tensor_applied):
#     805     if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     806         # If the new tensor has compatible tensor type as the existing tensor,
#     807         # the current behavior is to change the tensor in-place using `.data =`,
#    (...)
#     812         # global flag to let the user control whether they want the future
#     813         # behavior of overwriting the existing tensor or not.
#
# File ~/50024/kaggle/kaggle_env/lib/python3.11/site-packages/torch/nn/modules/module.py:802, in Module._apply(self, fn, recurse)
#     800 if recurse:
#     801     for module in self.children():
# --> 802         module._apply(fn)
#     804 def compute_should_use_set_data(tensor, tensor_applied):
#     805     if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     806         # If the new tensor has compatible tensor type as the existing tensor,
#     807         # the current behavior is to change the tensor in-place using `.data =`,
#    (...)
#     812         # global flag to let the user control whether they want the future
#     813         # behavior of overwriting the existing tensor or not.
#
# File ~/50024/kaggle/kaggle_env/lib/python3.11/site-packages/torch/nn/modules/module.py:825, in Module._apply(self, fn, recurse)
#     821 # Tensors stored in modules are graph leaves, and we don't want to
#     822 # track autograd history of `param_applied`, so we have to use
#     823 # `with torch.no_grad():`
#     824 with torch.no_grad():
# --> 825     param_applied = fn(param)
#     826 should_use_set_data = compute_should_use_set_data(param, param_applied)
#     827 if should_use_set_data:
#
# File ~/50024/kaggle/kaggle_env/lib/python3.11/site-packages/torch/nn/modules/module.py:1150, in Module.to.<locals>.convert(t)
#    1147 if convert_to_format is not None and t.dim() in (4, 5):
#    1148     return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None,
#    1149                 non_blocking, memory_format=convert_to_format)
# -> 1150 return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None, non_blocking)
#
# RuntimeError: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.

# %% [markdown]
# #### Perfom MTCNN facial detection
#
# Iterate through the DataLoader object and obtain cropped faces.

# %%
def filter_RGB(image):
    if image.mode != 'RGB':
        image = image.convert('RGB')
    return image

class FilterRGB(object):
    def __call__(self, img):
        filtered_img = filter_RGB(img)
        if filtered_img is None:
            return None
        return filtered_img
    
transform = transforms.Compose([
    transforms.Resize((512, 512)),
    FilterRGB(),
])

dataset = datasets.ImageFolder(data_dir, transform=transform)
class_to_idx = {class_name: idx for idx, class_name in enumerate(dataset.classes)}
idx_to_class = {idx: class_name for class_name, idx in class_to_idx.items()}
dataset.samples = [
    (p, p.replace(data_dir, data_dir + '_cropped'))
        for p, _ in dataset.samples
]
        
loader = DataLoader(
    dataset,
    num_workers=workers,
    batch_size=128,
    collate_fn=training.collate_pil
)

# %% [markdown]
# #### Define Inception Resnet V1 module
#
# See `help(InceptionResnetV1)` for more details.

# %%
resnet = InceptionResnetV1(
    classify=True,
    # pretrained='vggface2',
    pretrained='casia-webface',
    num_classes=100
).to(device)

# %% [markdown]
# #### Define optimizer, scheduler, dataset, and dataloader

# %%
optimizer = optim.Adam(resnet.parameters(), lr=0.001)
scheduler = MultiStepLR(optimizer, [3, 4])

trans = transforms.Compose([
    np.float32,
    transforms.ToTensor(),
    fixed_image_standardization
])
dataset = datasets.ImageFolder('/home/obasit/50024/kaggle/data/export2_data/kaggle_data/train/train_mtcnn_inlcuding_grey_512_20_smallest_face_prob_90_single_faces', transform=trans)
class_to_idx = {class_name: idx for idx, class_name in enumerate(dataset.classes)}
idx_to_class = {idx: class_name for class_name, idx in class_to_idx.items()}

img_inds = np.arange(len(dataset))
np.random.shuffle(img_inds)
train_inds = img_inds[:int(0.85 * len(img_inds))]
val_inds = img_inds[int(0.85 * len(img_inds)):]

train_loader = DataLoader(
    dataset,
    num_workers=workers,
    batch_size=batch_size,
    sampler=SubsetRandomSampler(train_inds)
)
val_loader = DataLoader(
    dataset,
    num_workers=workers,
    batch_size=batch_size,
    sampler=SubsetRandomSampler(val_inds)
)

# %%
train_inds1 = img_inds[:int(0.33 * len(img_inds))]
train_inds2 = img_inds[int(0.33 * len(img_inds)):int(0.66 * len(img_inds))]
train_inds3 = img_inds[int(0.66 * len(img_inds)):]

train_loader1 = DataLoader(
    dataset,
    num_workers=workers,
    batch_size=batch_size,
    sampler=SubsetRandomSampler(np.concatenate([train_inds1, train_inds2]))
)
val_loader1 = DataLoader(
    dataset,
    num_workers=workers,
    batch_size=batch_size,
    sampler=SubsetRandomSampler(train_inds3)
)

train_loader2 = DataLoader(
    dataset,
    num_workers=workers,
    batch_size=batch_size,
    sampler=SubsetRandomSampler(np.concatenate([train_inds2, train_inds3[:-5]]))
)
val_loader2 = DataLoader(
    dataset,
    num_workers=workers,
    batch_size=batch_size,
    sampler=SubsetRandomSampler(train_inds1)
)

train_loader3 = DataLoader(
    dataset,
    num_workers=workers,
    batch_size=batch_size,
    sampler=SubsetRandomSampler(np.concatenate([train_inds3, train_inds1[:-5]]))
)
val_loader3 = DataLoader(
    dataset,
    num_workers=workers,
    batch_size=batch_size,
    sampler=SubsetRandomSampler(train_inds2)
)

# %% [markdown]
# #### Define loss and evaluation functions

# %%
loss_fn = torch.nn.CrossEntropyLoss()
metrics = {
    'fps': training.BatchTimer(),
    'acc': training.accuracy
}

# %% [markdown]
# #### Train model

# %%
writer = SummaryWriter()
writer.iteration, writer.interval = 0, 10

print('\n\nInitial')
print('-' * 10)
resnet.eval()
training.pass_epoch(
    resnet, loss_fn, val_loader,
    batch_metrics=metrics, show_running=True, device=device,
    writer=writer
)

for epoch in range(5):
    print('\nEpoch {}/{}'.format(epoch + 1, epochs))
    print('-' * 10)

    resnet.train()
    training.pass_epoch(
        resnet, loss_fn, train_loader, optimizer, scheduler,
        batch_metrics=metrics, show_running=True, device=device,
        writer=writer
    )

    resnet.eval()
    training.pass_epoch(
        resnet, loss_fn, val_loader,
        batch_metrics=metrics, show_running=True, device=device,
        writer=writer
    )


writer.close()

torch.save(resnet.state_dict(), 'facenet_model_train_mtcnn_inlcuding_grey_512_20_smallest_face_prob_80_single_faces_casia.pth')
# Out:
# Initial
# ----------
# Valid |   241/241  | loss:    4.7904 | fps: 1254.8101 | acc:    0.0106
#
# Epoch 1/7
# ----------
# Train |  1366/1366 | loss:    2.0594 | fps:  536.8164 | acc:    0.5443
# Valid |   241/241  | loss:    1.5744 | fps: 1334.1681 | acc:    0.6696
#
# Epoch 2/7
# ----------
# Train |  1366/1366 | loss:    1.2984 | fps:  542.9641 | acc:    0.7248
# Valid |   241/241  | loss:    1.3563 | fps: 1277.0341 | acc:    0.7191
#
# Epoch 3/7
# ----------
# Train |  1366/1366 | loss:    1.0091 | fps:  558.0370 | acc:    0.7799
# Valid |   241/241  | loss:    1.2327 | fps: 1328.6702 | acc:    0.7535
#
# Epoch 4/7
# ----------
# Train |  1366/1366 | loss:    0.5190 | fps:  540.1210 | acc:    0.8840
# Valid |   241/241  | loss:    0.9475 | fps: 1327.7325 | acc:    0.8195
#
# Epoch 5/7
# ----------
# Train |  1366/1366 | loss:    0.3403 | fps:  509.6160 | acc:    0.9230
# Valid |   241/241  | loss:    0.9428 | fps: 1214.0343 | acc:    0.8201

# %% [markdown]
# ### Testing

# %%
preprocess = transforms.Compose([
    np.float32,
    transforms.ToTensor(),
    fixed_image_standardization
])

resize_t = transforms.Compose([
    transforms.Resize((160, 160)),
])

class CelebrityDatasetTest(torch.utils.data.Dataset):
    def __init__(self, images_dir, transform=None):
        self.images_dir = images_dir
        self.transform = transform

    def __len__(self):
        count = 0
        for name in glob.glob('/home/obasit/50024/kaggle/data/test/test/' + '*.jpg'):
            count += 1
        return count
    
    def __getitem__(self, idx):
        if torch.is_tensor(idx):
            idx = idx.tolist()

        img_name = os.path.join(self.images_dir + str(idx) + '.jpg')
        
        try:
            image = Image.open(img_name)
        except:
            try:
                img_name = os.path.join('/home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/' + str(idx) + '.jpg')
                image = Image.open(img_name)
                if image.mode != 'RGB':
                    image = image.convert('RGB')
                print("found in here", img_name)
            except:
                img_name = os.path.join('/home/obasit/50024/kaggle/data/test/test/' + str(idx) + '.jpg')
                image = Image.open(img_name)
                image = resize_t(image) 
                if image.mode != 'RGB':
                    image = image.convert('RGB')
                print("found in here", img_name)
            

        image = preprocess(image)  

        sample = {'image': image, 'Id': idx}

        if self.transform:
            sample = self.transform(sample)

        return sample
    
batch_size = 32

testset = CelebrityDatasetTest(images_dir='/home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_mtcnn_inlcuding_grey_512_20_smallest_face_prob_98/')
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size,
                                         shuffle=False, num_workers=1)

df = pd.read_csv('/home/obasit/50024/kaggle/data/category.csv')
classes = df['Category'].to_list()

# %%
resnet.to(device)

categories_df = pd.read_csv('/home/obasit/50024/kaggle/data/category.csv', index_col=0)
bigger_df = pd.DataFrame(columns=['Id', 'Category'])

# since we're not training, we don't need to calculate the gradients for our outputs
with torch.no_grad():
    for data in testloader:
        images, Id = data['image'].to(device), data['Id'].to(device)

        # calculate outputs by running images through the network
        outputs = resnet(images)
        
        # the class with the highest energy is what we choose as prediction
        _, predicted = torch.max(outputs.data, 1)

        one_id = {
            'Id': Id.tolist(),
            'Category': [idx_to_class[idx] for idx in predicted.tolist()]
        }

        one_id_df = pd.DataFrame.from_dict(one_id)
        
        bigger_df = pd.concat([bigger_df, one_id_df], ignore_index=True)
        



bigger_df['Category'] = bigger_df['Category'].str.replace('_', ' ')
print(bigger_df)
bigger_df.to_csv('facenet_model_train_mtcnn_inlcuding_grey_512_20_smallest_face_prob_80_single_faces_casia.csv')
# Out:
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/5.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/63.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/75.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/107.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/112.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/123.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/132.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/133.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/166.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/183.jpg
# found in here /home/obasit/50024/kaggle/data/test/test/210.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/217.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/228.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/235.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/238.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/269.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/273.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/274.jpg
# found in here /home/obasit/50024/kaggle/data/test/test/282.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/314.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/315.jpg
# found in here /home/obasit/50024/kaggle/data/test/test/317.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/320.jpg
# found in here /home/obasit/50024/kaggle/data/test/test/328.jpg
# found in here /home/obasit/50024/kaggle/data/test/test/343.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/361.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/376.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/397.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/447.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/484.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/499.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/518.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/519.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/543.jpg
# found in here /home/obasit/50024/kaggle/data/test/test/545.jpg
# found in here /home/obasit/50024/kaggle/data/test/test/585.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/608.jpg
# found in here /home/obasit/50024/kaggle/data/test/test/609.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/645.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/670.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/672.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/693.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/698.jpg
# found in here /home/obasit/50024/kaggle/data/test/test/701.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/721.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/731.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/780.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/804.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/851.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/856.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/857.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/867.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/876.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/916.jpg
# found in here /home/obasit/50024/kaggle/data/test/test/927.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/973.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/1036.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/1085.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/1095.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/1141.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/1142.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/1154.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/1197.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/1200.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/1211.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/1259.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/1277.jpg
# found in here /home/obasit/50024/kaggle/data/test/test/1336.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/1351.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/1362.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/1389.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/1395.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/1458.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/1466.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/1474.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/1475.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/1477.jpg
# found in here /home/obasit/50024/kaggle/data/test/test/1480.jpg
# found in here /home/obasit/50024/kaggle/data/test/test/1499.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/1508.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/1514.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/1531.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/1569.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/1571.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/1622.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/1629.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/1639.jpg
# found in here /home/obasit/50024/kaggle/data/test/test/1658.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/1665.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/1690.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/1704.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/1708.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/1722.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/1723.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/1735.jpg
# found in here /home/obasit/50024/kaggle/data/test/test/1749.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/1780.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/1814.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/1816.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/1848.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/1855.jpg
# found in here /home/obasit/50024/kaggle/data/test/test/1868.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/1894.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/1901.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/1908.jpg
# found in here /home/obasit/50024/kaggle/data/test/test/1922.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/1961.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/1969.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/1984.jpg
# found in here /home/obasit/50024/kaggle/data/test/test/1997.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/2008.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/2037.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/2063.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/2088.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/2116.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/2140.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/2158.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/2171.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/2175.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/2235.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/2237.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/2277.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/2296.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/2388.jpg
# found in here /home/obasit/50024/kaggle/data/test/test/2411.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/2421.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/2440.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/2442.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/2517.jpg
# found in here /home/obasit/50024/kaggle/data/test/test/2523.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/2591.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/2592.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/2608.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/2635.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/2637.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/2655.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/2679.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/2680.jpg
# found in here /home/obasit/50024/kaggle/data/test/test/2777.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/2792.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/2864.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/2880.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/2969.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/2970.jpg
# found in here /home/obasit/50024/kaggle/data/test/test/3010.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/3020.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/3029.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/3045.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/3049.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/3053.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/3056.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/3076.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/3094.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/3137.jpg
# found in here /home/obasit/50024/kaggle/data/test/test/3148.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/3177.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/3267.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/3310.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/3313.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/3320.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/3322.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/3329.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/3368.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/3389.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/3401.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/3416.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/3418.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/3422.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/3426.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/3434.jpg
# found in here /home/obasit/50024/kaggle/data/test/test/3437.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/3454.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/3458.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/3459.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/3469.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/3471.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/3482.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/3486.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/3488.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/3543.jpg
# found in here /home/obasit/50024/kaggle/data/test/test/3558.jpg
# found in here /home/obasit/50024/kaggle/data/test/test/3568.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/3571.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/3669.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/3699.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/3708.jpg
# found in here /home/obasit/50024/kaggle/data/test/test/3731.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/3735.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/3744.jpg
# found in here /home/obasit/50024/kaggle/data/test/test/3752.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/3791.jpg
# found in here /home/obasit/50024/kaggle/data/test/test/3819.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/3822.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/3851.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/3857.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/3858.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/3892.jpg
# found in here /home/obasit/50024/kaggle/data/test/test/3905.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/3927.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/3929.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/3952.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/3980.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/3987.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/4004.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/4109.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/4133.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/4143.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/4177.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/4190.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/4204.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/4206.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/4227.jpg
# found in here /home/obasit/50024/kaggle/data/test/test/4237.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/4260.jpg
# found in here /home/obasit/50024/kaggle/data/test/test/4296.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/4303.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/4321.jpg
# found in here /home/obasit/50024/kaggle/data/test/test/4337.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/4341.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/4342.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/4350.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/4385.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/4386.jpg
# found in here /home/obasit/50024/kaggle/data/test/test/4390.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/4398.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/4407.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/4430.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/4541.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/4543.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/4567.jpg
# found in here /home/obasit/50024/kaggle/data/test/test/4610.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/4620.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/4654.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/4656.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/4666.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/4684.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/4692.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/4697.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/4703.jpg
# found in here /home/obasit/50024/kaggle/data/test/test/4757.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/4768.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/4778.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/4817.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/4847.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/4882.jpg
# found in here /home/obasit/50024/kaggle/data/test/test/4888.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/4923.jpg
# found in here /home/obasit/50024/kaggle/data/export2_data/kaggle_data/test/test_dfsd_inlcuding_grey/4934.jpg
#         Id         Category
# 0        0      Ben Johnson
# 1        1         Amy Ryan
# 2        2     Adrien Brody
# 3        3  Adriana Barraza
# 4        4    Albert Brooks
# ...    ...              ...
# 4972  4972  Barabara Palvin
# 4973  4973         Anna Sui
# 4974  4974       Bill Hader
# 4975  4975      Amanda Crew
# 4976  4976     bella thorne
#
# [4977 rows x 2 columns]
